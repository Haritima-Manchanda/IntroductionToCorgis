# %% [markdown]
# # School Scores Python Library
# From the CORGIS Dataset Project
#
# By Haritima Manchanda haritima@udel.edu <br/>
# Version 3.7.1, created 3/21/2021 <br/>
# Tags: school, education, K-12, kindergarten, learning, teaching, sat
#
# # Overview
# SAT Scores from across the country
#
# <a href=’https://nces.ed.gov/ccd/aboutCCD.asp’>https://nces.ed.gov/ccd/aboutCCD.asp</a>
#
# <a href=’https://nces.ed.gov/programs/digest/d10/tables/dt10_154.asp’>https://nces.ed.gov/programs/digest/d10/tables/dt10_154.asp</a>
#
# # Downloads
# Download all of the following files:
#
# 1. [school_scores.py](https://corgis-edu.github.io/corgis/datasets/python/school_scores/school_scores.py)
# 2. [school_scores.data](https://corgis-edu.github.io/corgis/datasets/python/school_scores/school_scores.data)
#
# # USAGE

# %%
import school_scores
record = school_scores.get_record()

# %% [markdown]
# # Documentation
# **get_record()** <br/>
# Returns a list of dictionaries representing record.
#
# &copy; 2020 CORGIS Datasets Project. Project by Austin Cory Bart, Dennis Kafura, Clifford A. Shaffer, Javier Tibau, Luke Gusukuma, Eli Tilevich.
